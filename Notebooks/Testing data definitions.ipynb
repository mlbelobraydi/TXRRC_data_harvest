# %% [markdown]
# # Notebook to test the layouts for each section
# This notebook opens and reads teh dbf900.ebc.gz file then starts to parse the data from each section

# %% [markdown]
# ## Import, read, and convert file to array of strings

# %%
import pandas as pd
import ebcdic
import codecs

file = r'C:\PublicData\Texas\TXRRC\index\dbf900.ebc' ##Local storage location
##file origin: ftp://ftpe.rrc.texas.gov/shfwba/dbf900.ebc.gz

with open(file, 'rb') as ebcdic: #Reads the .ebc file
    data = ebcdic.read()

ascii_txt = codecs.decode(data, 'cp1140') #decodes the entire .ebc file to ascii

split_records = []

block_size  = 247 ##block size for each record in the file
##Unknown if this holds true for all versions of this file or for other files on TXRRC

for index in range(0, len(ascii_txt), block_size): ##Creates an array for all records in the file
    split_records.append(ascii_txt[index : index + block_size])

# %% [markdown]
# ## DEF to return the correct definition layout for each record in file

# %%
def get_layout(startval):
    WBROOT_01 = [
            ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
            ('WELL-BORE-API-ROOT',2,8,'pic_numeric'), ## Combines WB-API-CNTY and WB-API-UNIQUE
            ('WB-NXT-AVAIL-SUFFIX',10,2,'pic_numeric'),
            ('WB-NXT-AVAIL-HOLE-CHGE-NBR',12,2,'pic_numeric'),
            ('WB-FIELD-DISTRICT',14,2,'pic_numeric'),
            ('WB-RES-CNTY-CODE',16,3,'pic_numeric'),
            ('WB-ORIG-COMPL-DATE',20,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-ORIG-COMPL-CENT&YY&MM&DD
            ('WB-TOTAL-DEPTH',28,5,'pic_numeric'),
            ('WB-VALID-FLUID-LEVEL',33,5,'pic_numeric'),
            ('WB-CERTIFICATION-REVOKED-DATE',38,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-CERT-REVOKED-CC&YY&MM&DD
            ('WB-CERTIFICATION-DENIAL-DATE',46,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-CERTIFICATION-DENIAL-CC&YY&MM&DD
            ('WB-DENIAL-REASON-FLAG',56,1,'pic_any'),
            ('WB-ERROR-API-ASSIGN-CODE',55,1,'pic_any'),
            ('WB-REFER-CORRECT-API-NBR',56,8,'pic_numeric'),
            ('WB-DUMMY-API-NUMBER',64,8,'pic_numeric'),
            ('WB-DATE-DUMMY-REPLACED',72,8,'pic_yyyymmdd'), ##YYYYMMDD
            ('WB-NEWEST-DRL-PMT-NBR',80,6,'pic_numeric'),
            ('WB-CANCEL-EXPIRE-CODE',86,1,'pic_any'),
            ('WB-EXCEPT-13-A',88,1,'pic_any'),
            ('WB-FRESH-WATER-FLAG',89,1,'pic_any'),
            ('WB-PLUG-FLAG',90,1,'pic_any'),
            ('WB-PREVIOUS-API-NBR',91,8,'pic_numeric'),
            ('WB-COMPLETION-DATA-IND',99,1,'pic_any'),
            ('WB-HIST-DATE-SOURCE-FLAG',100,1,'pic_numeric'),
            ('WB-EX14B2-COUNT',102,2,'pic_numeric'),
            ('WB-DESIGNATION-HB-1975-FLAG',104,1,'pic_any'),
            ('WB-DESIGNATION-EFFECTIVE-DATE',105,6,'pic_yyyymm'), ##YYYYMM Combines WB-DESIGNATION-EFFEC-CC&YY&MM
            ('WB-DESIGNATION-REVISED-DATE',111,6,'pic_yyyymm'), ##YYYYMM Combines WB-DESIGNATION-REVISED-CC&YY&MM
            ('WB-DESIGNATION-LETTER-DATE',117,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-DESIGNATION-LETTER-CC&YY&MM&DD
            ('WB-CERTIFICATION-EFFECT-DATE',125,6,'pic_yyyymm'), ##YYYYMM Combines WB-CERTIFICATION-EFFEC-CC&YY&MM
            ('WB-WATER-LAND-CODE',131,1,'pic_any'),
            ('WB-TOTAL-BONDED-DEPTH',132,6,'pic_numeric'),
            ('WB-OVERRIDE-EST-PLUG-COST',138,7,'pic_numeric'),
            ('WB-SHUT-IN-DATE',145,6,'pic_numeric'), ##YYYYMM
            ('WB-OVERRIDE-BONDED-DEPTH',151,6,'pic_numeric'),
            ('WB-SUBJ-TO-14B2-FLAG',157,1,'pic_any'),
            ('WB-PEND-REMOVAL-14B2-FLAG',158,1,'pic_any'),
            ('WB-ORPHAN-WELL-HOLD-FLAG',159,1,'pic_any'),
            ('WB-W3X-WELL-FLAG',160,1,'pic_any')
            ]

    WBCOMPL_02 =[
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-OIL-GAS-INFO',2,14,'pic_any'),##Needs to be separated out later for oil and gas wells
                ('WB-GAS-DIST',16,2,'pic_numeric'),
                ('WB-GAS-WELL-NO',18,6,'pic_any'),
                ('WB-MULTI-WELL-REC-NBR',24,1,'pic_any'),
                ('WB-API-SUFFIX',25,2,'pic_numeric'),
                ('WB-ACTIVE-INACTIVE-CODE',45,1,'pic_any'),
                ('WB-DWN-HOLE-COMMINGLE-CODE',86,1,'pic_any'),
                ('WB-CREATED-FROM-PI-FLAG',121,1,'pic_any'),
                ('WB-RULE-37-NBR',122,7,'pic_numeric'),
                ('WB-P-15',155,1,'pic_any'),
                ('WB-P-12',156,1,'pic_any'),
                ('WB-PLUG-DATE-POINTER',157,8,'pic_numeric')
                ]
    #for WBCOMPL_02 'WB-OIL-GAS-INFO' needs to be separated based on fluid type (could be dry and null?)
    # if oil    ('WB-OIL',2,1,'pic_any'),
    #           ('WB-OIL-DISTRICT',3,2,'pic_numeric'),
    #           ('WB-OIL-LSE-NUMBER',5,5,'pic_numeric'),
    #           ('WB-OIL-WELL-NUMBER',10,6,'pic_any')
    #
    #if gas     ('WB-GAS',2,1,'pic_any'),
    #           ('WB-GAS-RRCID',3,6,'pic_numeric')

    WBDATE_03 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-FILE-KEY',2,8,'pic_numeric'),
                ('WB-FILE-DATE',10,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-EXCEPT-RULE-11',26,1,'pic_any'),
                ('WB-CEMENT-AFFIDAVIT',27,1,'pic_any'),
                ('WB-G-5',28,1,'pic_any'),
                ('WB-W-12',29,1,'pic_any'),
                ('WB-DIR-SURVEY',30,1,'pic_any'),
                ('WB-W2-G1-DATE ',31,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-COMPL-DATE',39,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-COMPL-CENTURY&YEAR&MONTH&DAY
                ('WB-DRL-COMPL-DATE',47,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-PLUGB-DEPTH1',55,5,'pic_numeric'),
                ('WB-PLUGB-DEPTH2',60,5,'pic_numeric'),
                ('WB-WATER-INJECTION-NBR',65,6,'pic_any'),
                ('WB-SALT-WTR-NBR',71,5,'pic_numeric'),
                ('WB-REMARKS-IND',84,1,'pic_any'),
                ('WB-ELEVATION',85,4,'pic_numeric'),
                ('WB-ELEVATION-CODE',89,2,'pic_any'),
                ('WB-LOG-FILE-RBA',91,8,'pic_numeric'),
                ('WB-DOCKET-NBR',99,10,'pic_any'),
                ('WB-PSA-WELL-FLAG',109,1,'pic_any'),
                ('WB-ALLOCATION-WELL-FLAG',110,1,'pic_any')
                ]

    WBRMKS_04 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-RMK-LNE-CNT',2,3,'pic_numeric'),
                ('WB-RMK-TYPE-CODE',5,1,'pic_any'),
                ('WB-REMARKS',6,70,'pic_any')
                ]

    WBTUBE_05 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-SEGMENT-COUNTER ',2,3,'pic_numeric'),
                ('WB-TUBING-INCHES',5,2,'pic_numeric'),
                ('WB-FR-NUMERATOR',7,2,'pic_numeric'),
                ('WB-FR-DENOMINATOR',9,2,'pic_numeric'),
                ('WB-DEPTH-SET',11,5,'pic_numeric'),
                ('WB-PACKER-SET',16,5,'pic_numeric')
                ]

    WBCASE_06 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-CASING-COUNT',2,3,'pic_numeric'),
                ('WB-CAS-INCH',5,2,'pic_numeric'),
                ('WB-CAS-FRAC-NUM',7,2,'pic_numeric'),
                ('WB-CAS-FRAC-DENOM',9,2,'pic_numeric'),
                ('WB-CAS-WT-TABLE',11,8,'pic_numeric'), ##ISSUE 03 WB-CASING-WEIGHT-LBS-FT REDEFINES WB-CAS-WT-TABLEOCCURS 2 TIMES.(05 WB-WGT-WHOLE PIC 9(03))(05 WB-WGT-TENTHS PIC 9(01))
                ('WB-CASING-DEPTH-SET',19,5,'pic_numeric'),
                ('WB-MLTI-STG-TOOL-DPTH',24,5,'pic_numeric'),
                ('WB-AMOUNT-OF-CEMENT',29,5,'pic_numeric'),
                ('WB-CEMENT-MEASUREMENT',34,1,'pic_any'), ##S = sacks, Y = yards, F = cubic feet
                ('WB-HOLE-INCH',35,2,'pic_numeric'),
                ('WB-HOLE-FRAC-NUM',37,2,'pic_numeric'),
                ('WB-HOLE-FRAC-DENOM',39,2,'pic_numeric'),
                ('WB-TOP-OF-CEMENT-CASING',42,7,'pic_any'),
                ('WB-AMOUNT-CASING-LEFT',49,5,'pic_numeric')
                ]

    WBPERF_07 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PERF-COUNT',2,3,'pic_numeric'),
                ('WB-FROM-PERF',5,5,'pic_numeric'),
                ('WB-TO-PERF',10,5,'pic_numeric'),
                ('WB-OPEN-HOLE-CODE',15,2,'pic_any') ##WB-OPEN-HOLE VALUE 'OH'
                ]

    WBLINE_08 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-LINE-COUNT',2,3,'pic_numeric'),
                ('WB-LIN-INCH',5,2,'pic_numeric'),
                ('WB-LIN-FRAC-NUM',7,2,'pic_numeric'),
                ('WB-LIN-FRAC-DENOM',9,2,'pic_numeric'),
                ('WB-SACKS-OF-CEMENT',11,5,'pic_numeric'),
                ('WB-TOP-OF-LINER',16,5,'pic_numeric'),
                ('WB-BOTTOM-OF-LINER',21,5,'pic_numeric')
                ]

    WBFORM_09 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-FORMATION-CNTR',2,3,'pic_numeric'),
                ('WB-FORMATION-NAME',5,32,'pic_any'),
                ('WB-FORMATION-DEPTH',37,5,'pic_numeric')
                ]

    WBSQEZE_10 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-SQUEEZE-CNTR ',2,3,'pic_numeric'),
                ('WB-SQUEEZE-UPPER-DEPTH ',5,5,'pic_numeric'),
                ('WB-SQUEEZE-LOWER-DEPTH',10,5,'pic_numeric'),
                ('WB-SQUEEZE-KIND-AMOUNT ',17,50,'pic_any')
                ]

    WBFRESH_11 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-FRESH-WATER-CNTR',2,3,'pic_numeric'),
                ('WB-TWDB-DATE',5,8,'pic_numeric'), #YYYYMMDD
                ('WB-SURFACE-CASING-DETER-CODE',13,1,'pic_any'), #WB-FIELD-RULE-CODE Y or N
                ('WB-UQWP-FROM',14,4,'pic_numeric'),
                ('WB-UQWP-TO',18,4,'pic_numeric')
                ]

    WBOLDLOC_12 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-LEASE-NAME',2,32,'pic_any'),
                ('WB-SEC-BLK-SURVEY-LOC',34,52,'pic_any'),
                ('WB-WELL-LOC-MILES',86,4,'pic_numeric'),
                ('WB-WELL-LOC-DIRECTION',90,6,'pic_any'),
                ('WB-WELL-LOC-NEAREST-TOWN',96,13,'pic_any'),
                ('WB-DIST-FROM-SURVEY-LINES',137,28,'pic_any'),
                ('WB-DIST-DIRECT-NEAR-WELL',165,28,'pic_any')
                ]

    WBNEWLOC_13 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-LOC-COUNTY',2,3,'pic_numeric'),
                ('WB-ABSTRACT',5,6,'pic_any'),
                ('WB-SURVEY',11,55,'pic_any'),
                ('WB-BLOCK-NUMBER',66,10,'pic_any'),
                ('WB-SECTION',76,8,'pic_any'),
                ('WB-ALT-SECTION',84,4,'pic_any'),
                ('WB-ALT-ABSTRACT',88,6,'pic_any'),
                ('WB-FEET-FROM-SUR-SECT-1',94,6,'pic_numeric'),
                ('WB-DIREC-FROM-SUR-SECT-1',100,13,'pic_any'),
                ('WB-FEET-FROM-SUR-SECT-2',113,6,'pic_numeric'),
                ('WB-DIREC-FROM-SUR-SECT-2',119,13,'pic_any'),
                ('WB-WGS84-LATITUDE',132,9,'pic_latlong'), ##PIC S9(3)V9(7) ##DDD.DDDDDDD ISSUE WITH characters at end of each section
                ('WB-WGS84-LONGITUDE',142,9,'pic_latlong'), ##PIC S9(3)V9(7) ##DDD.DDDDDDD ISSUE WITH characters at end of each section
                ('WB-PLANE-ZONE',157,2,'pic_numeric'),
                ('WB-PLANE-COORDINATE-EAST',159,9,'pic_coord'), ##PIC S9(8)V9(2) TX State plane ft NAD27 DDDDDDDD.DD ISSUE WITH characters at end of each section
                ('WB-PLANE-COORDINATE-NORTH',169,9,'pic_coord'), ##PIC S9(8)V9(2) TX State plane ft NAD27 DDDDDDDD.DD ISSUE WITH characters at end of each section
                ('WB-VERIFICATION-FLAG',177,1,'pic_any') #N = not verified, Y = verified, C = verified change
                ]

    WBPLUG_14 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-DATE-W3-FILED',2,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-DATE-WELL-BORE-PLUGGED',10,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-PLUG-TOTAL-DEPTH',18,5,'pic_numeric'),
                ('WB-PLUG-CEMENT-COMP',23,32,'pic_any'),
                ('WB-PLUG-MUD-FILLED',55,1,'pic_any'),
                ('WB-PLUG-MUD-APPLIED',56,12,'pic_any'),
                ('WB-PLUG-MUD-WEIGHT',68,3,'pic_numeric'),
                ('WB-PLUG-DRIL-PERM-DATE',75,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-PLUG-DRIL-PERM-NO',83,6,'pic_numeric'),
                ('WB-PLUG-DRIL-COMP-DATE',89,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-PLUG-LOG-ATTACHED',97,1,'pic_any'),
                ('WB-PLUG-LOG-RELEASED-TO',98,32,'pic_any'),
                ('WB-PLUG-TYPE-LOG',130,1,'pic_any'), ##D=Drillers E=Electric R=Radioactivity A=Acoustical-sonic F=Dril-and-Elec G=Elec-and-Radio H=radio-and-acous I=Dril-and-acous J=elec-and-acous K=dril-and-acous L=dril-elec-radio M=elec-radio-acous N=Dril-elec-acous O=dril-radio-acous P=dril-elec-radio-acous
                ('WB-PLUG-FRESH-WATER-DEPTH',131,5,'pic_numeric'),
                ('WB-PLUG-UWQP',136,40,'pic_any'), ##REDEFINES  WB-PLUG-UWQP. WB-PLUG-FROM-UWQP  OCCURS 4 TIMES PIC 9(05), WB-PLUG-TO-UWQP    OCCURS 4 TIMES PIC 9(05)
                ('WB-PLUG-MATERIAL-LEFT',176,1,'pic_any'),
                ('WB-OIL-GAS-INFO',177,14,'pic_any'),##Needs to be separated out later for oil and gas wells
                ('WB-PLUG-GAS-DIST',191,2,'pic_numeric'),
                ('WB-PLUG-GAS-WELL-NO',193,6,'pic_any'),
                ('WB-PLUG-TYPE-WELL',199,1,'pic_any'), ##O=Oil, G=Gas, D=Dry, S=Service
                ('WB-PLUG-MULTI-COMPL-FLAG',200,1,'pic_any'),
                ('WB-PLUG-CEM-AFF',201,1,'pic_any'), ##Y=WB-PLUG-CA-FILED N=WB-PLUG-CA-NOT-FILED
                ('WB-PLUG-13A',202,1,'pic_any'), ##Y=WB-PLUG-13A-FILED N=WB-PLUG-13A-NOT-FILED
                ('WB-PLUG-LOG-RELEASED-DATE',203,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-PLUG-LOG-FILE-RBA',211,8,'pic_numeric'),
                ('WB-STATE-FUNDED-PLUG-NUMBER',219,7,'pic_numeric')
                ]
    #for WBPLUG_14 'WB-OIL-GAS-INFO' needs to be separated based on fluid type (could be dry and null?)
    # if oil    ('WB-PLUG-OIL-CODE',177,1,'pic_any'), 
    #           ('WB-PLUG-OIL-DIST',178,2,'pic_numeric'), 
    #           ('WB-PLUG-OIL-LSE-NBR',180,5,'pic_numeric'), 
    #           ('WB-PLUG-OIL-WELL-NBR',185,6,'pic_any'), 
    #
    #if gas     ('WB-GAS',177,1,'pic_any'),
    #           ('WB-GAS-RRCID',178,6,'pic_numeric')

    WBPLRMKS_15 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PLUG-RMK-LNE-CNT',2,3,'pic_numeric'),
                ('WB-PLUG-RMK-TYPE-CODE',5,1,'pic_any'),
                ('WB-PLUG-REMARKS',6,70,'pic_any')
                ]

    WBPLREC_16 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PLUG-NUMBER',2,3,'pic_numeric'),
                ('WB-NBR-OF-CEMENT-SACKS',5,5,'pic_numeric'),
                ('WB-MEAS-TOP-OF-PLUG',10,5,'pic_numeric'),
                ('WB-BOTTOM-TUBE-PIPE-DEPTH',15,5,'pic_numeric'),
                ('WB-PLUG-CALC-TOP',20,5,'pic_numeric'),
                ('WB-PLUG-TYPE-CEMENT',25,6,'pic_any')
                ]

    WBPLCASE_17 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PLG-CAS-COUNTER',2,6,'pic_numeric'),
                ('WB-PLUG-CAS-INCH',8,2,'pic_numeric'),
                ('WB-PLUG-CAS-FRAC-NUM',10,2,'pic_numeric'),
                ('WB-PLUG-CAS-FRAC-DENOM',12,2,'pic_numeric'),
                ('WB-PLUG-WGT-WHOLE',14,3,'pic_numeric'),
                ('WB-PLUG-WGT-TENTHS',17,1,'pic_numeric'),
                ('WB-PLUG-AMT-PUT',18,5,'pic_numeric'),
                ('WB-PLUG-AMT-LEFT',23,5,'pic_numeric'),
                ('WB-PLUG-HOLE-INCH',28,2,'pic_numeric'),
                ('WB-PLUG-HOLE-FRAC-NUM',30,2,'pic_numeric'),
                ('WB-PLUG-HOLE-FRAC-DENOM',32,2,'pic_numeric')
                ]

    WBPLPERF_18 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PLUG-PERF-COUNTER',2,3,'pic_numeric'),
                ('WB-PLUG-FROM-PERF',5,5,'pic_numeric'),
                ('WB-PLUG-TO-PERF',10,5,'pic_numeric'),
                ('WB-PLUG-OPEN-HOLE-INDICATOR',15,1,'pic_any')
                ]

    WBPLNAME_19 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PLUG-FIELD-NO',2,8,'pic_numeric'),
                ('WB-PLUG-FIELD-NAME',10,32,'pic_any'),
                ('WB-PLUG-OPER-NO',42,6,'pic_any'),
                ('WB-PLUG-OPER-NAME',48,32,'pic_any'),
                ('WB-PLUG-LEASE-NAME',80,32,'pic_any')
                ]

    WBDRILL_20 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-PERMIT-NUMBER',2,6,'pic_numeric')
                ]

    WBWELLID_21 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-OIL-GAS-INFO',2,14,'pic_any'),##Needs to be separated out later for oil and gas wells
                ]
    #for WBWELLID_21 'WB-OIL-GAS-INFO' needs to be separated based on fluid type (could be dry and null?)
    # if oil    ('WB-OIL',2,1,'pic_any'),
    #           ('WB-OIL-DISTRICT',3,2,'pic_numeric'),
    #           ('WB-OIL-LSE-NUMBER',5,5,'pic_numeric'),
    #           ('WB-OIL-WELL-NUMBER',10,6,'pic_any')
    #
    #if gas     ('WB-GAS',2,1,'pic_any'),
    #           ('WB-GAS-RRCID',3,6,'pic_numeric')


    WB14B2_22 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-OIL-GAS-INFO',2,14,'pic_any'), ##Needs to be separated out later for oil and gas wells
                ('WB14B2-APPLICATION-NUMBER',16,6,'pic_numeric'),
                ('WB14B2-GAS-DISTRICT',22,2,'pic_numeric'),
                ('WB14B2-EXT-STATUS-FLAG',24,1,'pic_any'), ##A=approved C=cancelled D=Denied E=Expired
                ('WB14B2-EXT-CANCELLED-REASON',25,1,'pic_any'), ##I=injection P=producing G=plugged S=Service O=cancelled-other
                ('WB14B2-EXT-APPROVED-DATE',26,8,'pic_yyyymmdd'), ##YYYYMMDD WB14B2-EXT-APPROVED CENT+YEAR+MONTH+DAY
                ('WB14B2-EXT-EXP-DATE',34,8,'pic_yyyymmdd'), ##YYYYMMDD WB14B2-EXT-EXP-CENT+YEAR+MONTH+DAY
                ('WB14B2-EXT-DENIED-DATE',42,8,'pic_yyyymmdd'), ##YYYYMMDD WB14B2-EXT-DENIED-CENT+YEAR+MONTH+DAY
                ('WB14B2-EXT-HIST-DATE',50,8,'pic_yyyymmdd'), ##YYYYMMDD WB14B2-EXT-HIST-CENT+YEAR+MONTH+DAY
                ('WB14B2-MECH-INTEG-VIOL-FLAG',58,1,'pic_any'),## WB14B2-MECH-INTEG-VIOL VALUE 'H'
                ('WB14B2-PLUG-ORDER-SF-HOLD-FLAG',59,1,'pic_any'), ## WB14B2-PLUG-ORDER-SF-HOLD VALUE 'E'
                ('WB14B2-POLLUTION-VIOL-FLAG',60,1,'pic_any'), ## WB14B2-POLLUTION-VIOLVALUE 'P'
                ('WB14B2-FIELD-OPS-HOLD-FLAG',61,1,'pic_any'), ## WB14B2-FIELD-OPS-HOLD VALUE 'F'
                ('WB14B2-H15-PROBLEM-FLAG',62,1,'pic_any'), ## WB14B2-H15-PROBLEM VALUE 'V'
                ('WB14B2-H15-NOT-FILED-FLAG',63,1,'pic_any'), ## WB14B2-H15-NOT-FILED VALUE 'X'
                ('WB14B2-OPER-DELQ-FLAG',64,1,'pic_any'), ## WB14B2-OPER-DELQ VALUE 'O'
                ('WB14B2-DISTRICT-HOLD-SFP-FLAG',65,1,'pic_any'), ## WB14B2-DISTRICT-HOLD-SFP VALUE 'T'
                ('WB14B2-DIST-SF-CLEAN-UP-FLAG',66,1,'pic_any'), ## WB14B2-DIST-SF-CLEAN-UP VALUE 'M'
                ('WB14B2-DIST-STATE-PLUG-FLAG',67,1,'pic_any'), ## WB14B2-DIST-STATE-PLUG VALUE 'K'
                ('WB14B2-GOOD-FAITH-VIOL-FLAG',68,1,'pic_any'), ## WB14B2-GOOD-FAITH-VIOL VALUE 'R'
                ('WB14B2-WELL-OTHER-VIOL-FLAG',69,1,'pic_any'), ## WB14B2-WELL-OTHER-VIOL VALUE 'Q'
                ('WB14B2-W3C-SURF-EQP-VIOL-FLAG',70,1,'pic_any'), ## WB14B2-W3C-SURF-EQUIP-VIOL VALUE 'S'
                ('WB14B2-W3X-VIOL-FLAG',71,1,'pic_any'), ## WB14B2-W3X-VIOL VALUE 'W'
                ('WB14B2-HB2259-W3X-PUB-ENT',79,1,'pic_any'),
                ('WB14B2-HB2259-W3X-10PCT',80,1,'pic_any'),
                ('WB14B2-HB2259-W3X-BONDING',81,1,'pic_any'),
                ('WB14B2-HB2259-W3X-H13-EOR',82,1,'pic_any'), ## WB14B2-HB2259-EOR-REJECTED VALUE 'R'
                ('WB14B2-HB2259-W3X-AOP',83,1,'pic_any'), ## WB14B2-HB2259-AOP-REJECTEDVALUE 'R'
                ('WB14B2-HB2259-W3X-MIT',84,1,'pic_any'), ## WB14B2-HB2259-MIT-REJECTED VALUE 'R'
                ('WB14B2-HB2259-W3X-ESCROW',85,1,'pic_any'), ## WB14B2-HB2259-ESCROW-REJECTED VALUE 'R'
                ('WB14B2-W3X-FILING-KEY',86,8,'pic_numeric'),
                ('WB14B2-W3X-AOP-RECEIVED-DATE',94,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB14B2-W3X-AOP-FEE-RCVD-DATE',102,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB14B2-W3X-H15-FEE-RCVD-DATE',110,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB14B2-W3X-ESCROW-FUNDS',118,5,'pic_numeric'), ##ISSUE WB14B2-W3X-ESCROW-FUNDS         VALUE ZEROS PIC 9(05)V99.119 WB14B2-W3X-ESCROW-FUND-SPLIT REDEFINESWB14B2-W3X-ESCROW-FUNDS.07 WB14B2-W3X-ESCROW-FUND-WHOLE               PIC 9(05).07 WB14B2-W3X-ESCROW-FUND-DECIMAL             PIC 9(02).
                ('WB14B2-60-DAY-LETTER-SENT-FLAG',125,1,'pic_any'),
                ('WB14B2-W1X-36-NEEDS-BOND-FLAG',126,1,'pic_any'),
                ('WB14B2-W1X-36-TYPE-COVERAGE',127,1,'pic_any'),## WB14B2-W1X-36-BOND VALUE 'B'  WB14B2-W1X-36-LOC VALUE 'L'
                ('WB14B2-W1X-36-AMT-FILED',128,9,'pic_numeric'),
                ('WB14B2-W1X-36-SURETY',137,5,'pic_numeric'),
                ('WB14B2-W1X-36-EXP-DATE',142,8,'pic_yyyymmdd'), ##YYYYMMDD WB14B2-W1X-36-EXP-CENT+YEAR+MON+DAY
                ('WB14B2-W1X-36-BOND-NUMBER',150,20,'pic_any')
                ]
    #for WB14B2_22 'WB-OIL-GAS-INFO' needs to be separated based on fluid type (could be dry and null?)
    # if oil    ('WB-OIL',2,1,'pic_any'),
    #           ('WB-OIL-DISTRICT',3,2,'pic_numeric'),
    #           ('WB-OIL-LSE-NUMBER',5,5,'pic_numeric'),
    #           ('WB-OIL-WELL-NUMBER',10,6,'pic_any')
    #
    #if gas     ('WB-GAS',2,1,'pic_any'),
    #           ('WB-GAS-RRCID',3,6,'pic_numeric')


    WBH15_23 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-H15-DATE-KEY',2,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-H15-STATUS',10,1,'pic_any'), ##A=approved C=compliant D=delinquent N=not-approved P=approval-pending W=W3A-extension U=UIC E=no-test-proj-ext X=W1X-denied
                ('WB-H15-OPERATOR',11,6,'pic_numeric'),
                ('WB-H15-NEXT-TEST-DUE-DATE',17,6,'pic_yyyymm'), ##YYYYMM WB-NEXT-TEST-CCYY&MM 
                ('WB-H15-DISTRICT',23,2,'pic_numeric'),
                ('WB-H15-FIELD',25,8,'pic_numeric'),
                ('WB-H15-HIST-WELLBORE-FLAG',33,1,'pic_any'), ##D=drilling C=early-compl
                ('WB-H15-HIST-WELL-DATE',34,8,'pic_yyyymmdd'), ##YYYYMMDD WB-H15-HIST-WELL-CCYYMMDD
                ('WB-H15-W1X-WELL',42,1,'pic_any'),
                ('WB-H15-OIL-GAS-CODE',43,1,'pic_any'), ##G=gas O=oil
                ('WB-H15-LEASE-NBR',44,5,'pic_numeric'),
                ('WB-H15-WELL-NBR',49,6,'pic_any'),
                ('WB-H15-GASID-NBR',55,6,'pic_numeric'),
                ('WB-H15-TEST-DATE',61,8,'pic_yyyymmdd'), ##YYYYMMDD WB-H15-TEST-CC&YY&MM&DD
                ('WB-H15-BASE-USABLE-WATER',69,6,'pic_numeric'),
                ('WB-H15-TYPE-TEST-FLAG',75,1,'pic_any'), ##F=H15-fluid-test M=H15-mech-integ-test
                ('WB-H15-TOP-OF-FLUID',76,6,'pic_numeric'),
                ('WB-H15-FLUID-TEST-FLAG',82,1,'pic_any'), ##W=wire S=Sonic V=visual O=other
                ('WB-H15-MECH-INTEG-TEST-FLAG',83,1,'pic_any'), ##H=hydraulic O=integ-other
                ('WB-H15-MECH-TEST-REASON-FLAG',84,1,'pic_any'), ##A=substitute B=14B2-require
                ('WB-H15-ALTERNATE-TEST-PERIOD',85,2,'pic_numeric'),
                ('WB-H15-OTHER-MIT-TEST-TYPE',87,20,'pic_any'),
                ('WB-H15-STATUS-DATE',107,8,'pic_numeric'), ##WB-H15-STATUS-CC&YY&MM&DD
                ('WB-H15-NO-DATE-WELL-FLAG',115,1,'pic_any'), ##Y=WB-H15-NO-DATE-WELL
                ('WB-H15-RECORD-FROM-EDI-FLAG',116,1,'pic_any'), ##Y=WB-H15-RECORD-FROM-EDI
                ('WB-H15-KEYED-DATE',117,8,'pic_yyyymmdd'), ##YYYYMMDD WB-H15-KEYED-CC&YY&MM&DD
                ('WB-H15-CHANGED-DATE',125,8,'pic_yyyymmdd'), ##YYYYMMDD WB-H15-CHANGED-CC&YY&MM&DD
                ('WB-H15-PREVIOUS-STATUS',133,1,'pic_any'),
                ('WB-H15-UIC-TEST-FLAG',134,1,'pic_any'), ##U=WB-H15-UIC-H5-TEST
                ('WB-H15-2YRS-APPROVED-FLAG',135,1,'pic_any'), ##Y=WB-H15-2YRS-APPROVED
                ('WB-H15-MAIL-HOLD-FLAG',136,1,'pic_any'), ##Y=WB-H15-MAIL-HOLD
                ('WB-H15-10YR-INACTIVE-FLAG',137,1,'pic_any'),
                ('WB-H15-W3X-WELL-FLAG',138,1,'pic_any') ##Y=WB-H15-W3X-WELL
                ]


    WBH15RMK_24 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-H15-REMARK-KEY',2,3,'pic_numeric'),
                ('WB-H15-REMARK-TEXT',5,70,'pic_any')
                ]

    WBSB126_25 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-SB126-DESIGNATION-FLAG',2,1,'pic_any'), ##A=auto-designated M=manual-designated
                ('WB-SB126-DESIG-EFFECTIVE-DATE',3,6,'pic_yyyymm'), ##YYYYMM WB-SB126-DESIG-EFFEC-CC&YY&MM
                ('WB-SB126-DESIG-REVISED-DATE',9,6,'pic_yyyymm'), ##YYYYMM WB-SB126-DESIG-REVISED-CC&YY&MM
                ('WB-SB126-DESIG-LETTER-DATE',15,8,'pic_yyyymmdd'), ##YYYYMMDD WB-SB126-DESIG-LETTER-CC&YY&MM&DD
                ('WB-SB126-CERT-EFFECT-DATE',23,6,'pic_yyyymm'), ##YYYMM WB-SB126-CERT-EFFEC-CC&YY&MM
                ('WB-SB126-CERT-REVOKED-DATE',29,8,'pic_yyyymmdd'), ##YYYYMMDD WB-SB126-CERT-REVOKED-CC&YY&MM&DD
                ('WB-SB126-CERT-DENIAL-DATE',37,8,'pic_yyyymmdd'), ##YYYYMMDD WB-SB126-CERT-DENIAL-CC$YY&MM&DD
                ('WB-SB126-DENIAL-REASON-FLAG',45,1,'pic_any') ##A=denied-auto M=denied-manual
                ]

    WBDASTAT_26 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WBDASTAT-STAT-NUM',2,7,'pic_numeric'),
                ('WBDASTAT-UNIQ-NUM',9,2,'pic_numeric'),
                ('WBDASTAT-DELETED-FLAG',11,1,'pic_any')
                ]

    WBW3C_27 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-W3C-1YR-FLAG',2,1,'pic_any'),
                ('WB-W3C-1YR-FILED-DATE',3,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-W3C-1YR-FILING-OPER',11,6,'pic_numeric'),
                ('WB-W3C-5YR-FLAG',17,1,'pic_any'),
                ('WB-W3C-5YR-FILED-DATE',18,8,'pic_numeric'),
                ('WB-W3C-5YR-FILING-OPER',26,6,'pic_numeric'),
                ('WB-W3C-10YR-FLAG',32,1,'pic_any'),
                ('WB-W3C-10YR-FILED-DATE',33,8,'pic_numeric'),
                ('WB-W3C-10YR-FILING-OPER',41,6,'pic_numeric'),
                ('WB-W3C-14B2-REMOVAL-DATE',48,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-W3C-EXTENSION-FLAG',55,1,'pic_any'),
                ('WB-W3C-EXTENSION-DATE',56,8,'pic_yyyymmdd'), ##YYYYMMDD Combines WB-W3C-EXTENSION-YEAR&MONTH&DAY
                ('WB-W3C-5YR-FLAG-PREVIOUS',64,1,'pic_any'),
                ('WB-W3C-10YR-FLAG-PREVIOUS',65,1,'pic_any')
                ]

    WB14B2RM_28 = [
                ('RRC-TAPE-RECORD-ID',0,2,'pic_any'),
                ('WB-14B2-RMK-LNE-CNT',2,3,'pic_numeric'),
                ('WB-14B2-RMK-DATE',5,8,'pic_yyyymmdd'), ##YYYYMMDD
                ('WB-14B2-RMK-USERID',13,8,'pic_any'),
                ('WB-14B2-REMARKS',21,66,'pic_any')
                ]
    
    
    layouts_map = {
                    '01' : {'name': 'WBROOT', 'layout': WBROOT_01},
                    '02' : {'name': 'WBCOMPL', 'layout': WBCOMPL_02},
                    '03' : {'name': 'WBDATE', 'layout': WBDATE_03},
                    '04' : {'name': 'WBRMKS', 'layout': WBRMKS_04},
                    '05' : {'name': 'WBTUBE', 'layout': WBTUBE_05},
                    '06' : {'name': 'WBCASE', 'layout': WBCASE_06},
                    '07' : {'name': 'WBPERF', 'layout': WBPERF_07},
                    '08' : {'name': 'WBLINE', 'layout': WBLINE_08},
                    '09' : {'name': 'WBFORM', 'layout': WBFORM_09},
                    '10' : {'name': 'WBSQEZE', 'layout': WBSQEZE_10},
                    '11' : {'name': 'WBFRESH', 'layout': WBFRESH_11},
                    '12' : {'name': 'WBOLDLOC', 'layout': WBOLDLOC_12},
                    '13' : {'name': 'WBNEWLOC', 'layout': WBNEWLOC_13},
                    '14' : {'name': 'WBPLUG', 'layout': WBPLUG_14},
                    '15' : {'name': 'WBPLRMKS', 'layout': WBPLRMKS_15},
                    '16' : {'name': 'WBPLREC', 'layout': WBPLREC_16},
                    '17' : {'name': 'WBPLCASE', 'layout': WBPLCASE_17},
                    '18' : {'name': 'WBPLPERF', 'layout': WBPLPERF_18},
                    '19' : {'name': 'WBPLNAME', 'layout': WBPLNAME_19},
                    '20' : {'name': 'WBDRILL', 'layout': WBDRILL_20},
                    '21' : {'name': 'WBWELLID', 'layout': WBWELLID_21},
                    '22' : {'name': 'WB14B2', 'layout': WB14B2_22},
                    '23' : {'name': 'WBH15', 'layout': WBH15_23},
                    '24' : {'name': 'WBH15RMK', 'layout': WBH15RMK_24},
                    '25' : {'name': 'WBSB126', 'layout': WBSB126_25},
                    '26' : {'name': 'WBDASTAT', 'layout': WBDASTAT_26},
                    '27' : {'name': 'WBW3C', 'layout': WBW3C_27},
                    '28' : {'name': 'WB14B2RM', 'layout': WB14B2RM_28}
                  }
    try:
        returnval = layouts_map[startval]
    except:
        returnval = None
    
    return returnval

# %% [markdown]
# ## DEFs for returning the correct formatted data

# %%
def pic_yyyymmdd(date):
    from datetime import datetime
    #Changes format YYYYMMDD from a series of numbers to datetime object
    try:
        val = datetime.strptime(date, '%Y%m%d').strftime('%m/%d/%Y')
    except ValueError:
        val = None
    return val
    
def pic_yyyymm(date):
    from datetime import datetime
    #Changes format YYYMM from a series of numbers to datetime object
    try:
        val = datetime.strptime(date, '%Y%m').strftime('%m/%Y')
    except ValueError:
        val = None
    return val
    
def pic_latlong(latlon, name): 
    ##DDDDDDDDD to DDD.DDDDDD
    try:
        val = float(str(int(latlon[0:3]))+'.'+str(int(latlon[3:9])))
        if 'LONGITUDE' in name:
            val = -val
    except ValueError:
        val = None
    return val

def pic_coord(coord):
    ##CCCCCCCC to CCCCCCC.C
    try:
        val = float(str(int(coord[0:8]))+'.'+str(int(record[8])))
    except ValueError:
        val = None    
    return val

def pic_numeric(num):
    try: ##using a try to ensure the values passed are actually 0-9 with no other characters
        val = int(num)
    except:
        val = None

    return val

def pic_any(string):
    STRIP_PIC_X = True # Set this to False if trimming PIC X causes problems.
    val = str(string)
    if STRIP_PIC_X == True:
        val = val.strip()

    return val

# %% [markdown]
# ## DEF for selecting the correct formatting for each field

# %%
def parse_record(record, layout):
    values = dict()

    for name, start, size, convert in layout:
        if convert == 'pic_yyyymmdd':
            values[name] = pic_yyyymmdd(record[start:start+size])
        elif convert == 'pic_yyyymm':
            values[name] = pic_yyyymmdd(record[start:start+size])
        elif convert == 'pic_latlong':
            values[name] = pic_latlong(record[start:start+size], name)
        elif convert == 'pic_coord':
            values[name] = pic_coord(record[start:start+size])
        elif convert == 'pic_numeric':
            values[name] = pic_numeric(record[start:start+size])
        else:
            values[name] = pic_any(record[start:start+size])

    return values

# %% [markdown]
# ## Working section to play with read data from each record

# %%
API = None
ct = 0

sample_records = split_records[0:2000] ## Used for testing to reduce number of records to run

for record in sample_records:
    if record.startswith('01'):
        API = '42'+record[2:10]

    startval = str(record[0:2])
    layout = get_layout(startval)['layout']
    parsed_vals = parse_record(record, layout)
   
    ct+=1
    print(API, parsed_vals)
# Out:
# 4200100001 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100001, 'WB-NXT-AVAIL-SUFFIX': 1, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 1, 'WB-FIELD-DISTRICT': 6, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': '10/27/1963', 'WB-TOTAL-DEPTH': 0, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100001, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'N', 'WB-PREVIOUS-API-NBR': 0, 'WB-COMPLETION-DATA-IND': 'Y', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 13, 'WB-DESIGNATION-HB-1975-FLAG': 'A', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': '10/22/1993', 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 4023, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 199801, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': 'Y', 'WB-PEND-REMOVAL-14B2-FLAG': '', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '02', 'WB-OIL-GAS-INFO': 'O0604411   1', 'WB-GAS-DIST': 0, 'WB-GAS-WELL-NO': '', 'WB-MULTI-WELL-REC-NBR': '0', 'WB-API-SUFFIX': 0, 'WB-ACTIVE-INACTIVE-CODE': '', 'WB-DWN-HOLE-COMMINGLE-CODE': '', 'WB-CREATED-FROM-PI-FLAG': 'N', 'WB-RULE-37-NBR': 0, 'WB-P-15': 'N', 'WB-P-12': 'N', 'WB-PLUG-DATE-POINTER': 0}
# 4200100001 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80159887, 'WB-FILE-DATE': '01/12/1984', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': '12/05/1963', 'WB-COMPL-DATE': '10/27/1963', 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 0, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 0, 'WB-REMARKS-IND': 'N', 'WB-ELEVATION': 0, 'WB-ELEVATION-CODE': '', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 1, 'WB-CAS-INCH': 0, 'WB-CAS-FRAC-NUM': 0, 'WB-CAS-FRAC-DENOM': 0, 'WB-CAS-WT-TABLE': 0, 'WB-CASING-DEPTH-SET': 0, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 0, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 0, 'WB-HOLE-FRAC-NUM': 0, 'WB-HOLE-FRAC-DENOM': 0, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 0}
# 4200100001 {'RRC-TAPE-RECORD-ID': '07', 'WB-PERF-COUNT': 1, 'WB-FROM-PERF': 4021, 'WB-TO-PERF': 4023, 'WB-OPEN-HOLE-CODE': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 830589, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '11/25/2019', 'WB-H15-BASE-USABLE-WATER': 475, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 830, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20200106, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/06/2020', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/06/2020 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 830589, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '11/26/2018', 'WB-H15-BASE-USABLE-WATER': 475, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 830, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20190117, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/17/2019', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/17/2019 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 830589, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '12/28/2017', 'WB-H15-BASE-USABLE-WATER': 475, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 810, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20180118, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/18/2018', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/18/2018 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 699848, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '01/02/2017', 'WB-H15-BASE-USABLE-WATER': 475, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 771, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20170214, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '02/14/2017', 'WB-H15-CHANGED-DATE': '02/02/2017', 'WB-H15-PREVIOUS-STATUS': 'D', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '02022017 DELINQUENT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': '02/14/2017 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'C', 'WB-H15-OPERATOR': 699848, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '12/29/2014', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 769, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20160518, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/12/2015', 'WB-H15-CHANGED-DATE': '05/18/2016', 'WB-H15-PREVIOUS-STATUS': 'N', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/12/2015 PENDING - REFER TO DISTRICT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': 'ON 04/22/2015 AN H-15 WAS NOT APPROVED BY OGFKMKV  FROM DISTRICT 06'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 3, 'WB-H15-REMARK-TEXT': 'ON 06/18/2015 AN EXTENSION WAS GIVEN THAT WILL EXPIRE ON 07/18/2015'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 4, 'WB-H15-REMARK-TEXT': 'ON 08/18/2015 AN EXTENSION WAS GIVEN THAT WILL EXPIRE ON 10/18/2015'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 5, 'WB-H15-REMARK-TEXT': 'ON 11/18/2015 AN EXTENSION WAS GIVEN THAT WILL EXPIRE ON 01/18/2016'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 6, 'WB-H15-REMARK-TEXT': '05/18/2016 COMPLIANT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 699848, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '12/27/2013', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 770, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20140117, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/17/2014', 'WB-H15-CHANGED-DATE': '01/17/2014', 'WB-H15-PREVIOUS-STATUS': 'P', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/17/2014 PENDING - REFER TO DISTRICT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': 'ON 01/17/2014 AN H-15 WAS   APPROVED   BY OGFKMTB  FROM DISTRICT 06'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 699848, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '12/28/2012', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 768, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20130208, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/31/2013', 'WB-H15-CHANGED-DATE': '02/08/2013', 'WB-H15-PREVIOUS-STATUS': 'P', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/31/2013 PENDING - REFER TO DISTRICT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': 'ON 02/08/2013 AN H-15 WAS   APPROVED   BY OGFKMTB  FROM DISTRICT 06'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 699848, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'O', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '12/30/2011', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 773, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20120113, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '01/10/2012', 'WB-H15-CHANGED-DATE': '01/13/2012', 'WB-H15-PREVIOUS-STATUS': 'P', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '', 'WB-H15-10YR-INACTIVE-FLAG': 'Y', 'WB-H15-W3X-WELL-FLAG': ''}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '01/10/2012 PENDING - REFER TO DISTRICT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': 'ON 01/13/2012 AN H-15 WAS   APPROVED   BY OGFKMTB  FROM DISTRICT 06'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '04/17/2011', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 778, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20110421, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '07/30/2003', 'WB-H15-CHANGED-DATE': '04/21/2011', 'WB-H15-PREVIOUS-STATUS': 'P', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '07072003 DELINQUENT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': '07/30/2003 A PROJECT EXT/NO TEST WAS GRANTED, EXPIRING ON 10/30/2003'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 3, 'WB-H15-REMARK-TEXT': '10/30/2003 H15 STATUS CHANGED FROM "E" TO "D"'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 4, 'WB-H15-REMARK-TEXT': '11/12/2003 A PROJECT EXT/NO TEST WAS GRANTED, EXPIRING ON 02/12/2004'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 5, 'WB-H15-REMARK-TEXT': '01/29/2004 A PROJECT EXT/NO TEST WAS GRANTED, EXPIRING ON 04/29/2004'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 6, 'WB-H15-REMARK-TEXT': '04/22/2004 A PROJECT EXT/NO TEST WAS GRANTED, EXPIRING ON 07/22/2004'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 7, 'WB-H15-REMARK-TEXT': '07/22/2004 H15 STATUS CHANGED FROM "E" TO "D"'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 8, 'WB-H15-REMARK-TEXT': '04/19/2011 PENDING - REFER TO DISTRICT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 9, 'WB-H15-REMARK-TEXT': 'ON 04/21/2011 AN H-15 WAS   APPROVED   BY OGFKMTB  FROM DISTRICT 06'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'D', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': '', 'WB-H15-HIST-WELL-DATE': None, 'WB-H15-W1X-WELL': 'Y', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': None, 'WB-H15-BASE-USABLE-WATER': 0, 'WB-H15-TYPE-TEST-FLAG': '0', 'WB-H15-TOP-OF-FLUID': 0, 'WB-H15-FLUID-TEST-FLAG': '', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 20011212, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '06/05/2001', 'WB-H15-CHANGED-DATE': '12/12/2001', 'WB-H15-PREVIOUS-STATUS': 'E', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': 'ON 06/05/2001 AN EXTENSION WAS GIVEN THAT WILL EXPIRE ON 08/04/2001'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': '08/06/2001 H15 STATUS CHANGED FROM "E" TO "D"'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 3, 'WB-H15-REMARK-TEXT': '09/12/2001 A PROJECT EXT/NO TEST WAS GRANTED, EXPIRING ON 12/12/2001'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 4, 'WB-H15-REMARK-TEXT': '12/12/2001 H15 STATUS CHANGED FROM "E" TO "D"'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '05/15/1999', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 900, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19990527, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '05/27/1999', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': 'Y', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '05/27/1999 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '03/05/1998', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 980, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19980312, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '03/12/1998', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '0', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '03/12/1998 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '07/21/1997', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 980, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19970730, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '07/30/1997', 'WB-H15-CHANGED-DATE': '07/07/1997', 'WB-H15-PREVIOUS-STATUS': 'D', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '0', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '07/07/97 DELINQUENT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': '07/30/1997 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '07/11/1996', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 960, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19960815, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '08/15/1996', 'WB-H15-CHANGED-DATE': '07/08/1996', 'WB-H15-PREVIOUS-STATUS': 'D', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '0', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '07/08/96 DELINQUENT'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': '08/15/1996 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'A', 'WB-H15-OPERATOR': 224830, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 16481001, 'WB-H15-HIST-WELLBORE-FLAG': 'C', 'WB-H15-HIST-WELL-DATE': '10/27/1963', 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 4411, 'WB-H15-WELL-NBR': '1', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': '05/27/1995', 'WB-H15-BASE-USABLE-WATER': 600, 'WB-H15-TYPE-TEST-FLAG': 'F', 'WB-H15-TOP-OF-FLUID': 950, 'WB-H15-FLUID-TEST-FLAG': 'S', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19950609, 'WB-H15-NO-DATE-WELL-FLAG': '', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': '06/09/1995', 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '0', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '06/09/1995 APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 1, 'WB-ABSTRACT': '', 'WB-SURVEY': 'ELLIS', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 32.1894, 'WB-WGS84-LONGITUDE': -96.3232, 'WB-PLANE-ZONE': 0, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '22', 'WB-OIL-GAS-INFO': 'O0604411   1', 'WB14B2-APPLICATION-NUMBER': 206677, 'WB14B2-GAS-DISTRICT': 0, 'WB14B2-EXT-STATUS-FLAG': 'A', 'WB14B2-EXT-CANCELLED-REASON': '\x00', 'WB14B2-EXT-APPROVED-DATE': '02/14/2020', 'WB14B2-EXT-EXP-DATE': '01/31/2019', 'WB14B2-EXT-DENIED-DATE': '01/31/2020', 'WB14B2-EXT-HIST-DATE': None, 'WB14B2-MECH-INTEG-VIOL-FLAG': '', 'WB14B2-PLUG-ORDER-SF-HOLD-FLAG': '', 'WB14B2-POLLUTION-VIOL-FLAG': '', 'WB14B2-FIELD-OPS-HOLD-FLAG': '', 'WB14B2-H15-PROBLEM-FLAG': '', 'WB14B2-H15-NOT-FILED-FLAG': '', 'WB14B2-OPER-DELQ-FLAG': '', 'WB14B2-DISTRICT-HOLD-SFP-FLAG': '', 'WB14B2-DIST-SF-CLEAN-UP-FLAG': '', 'WB14B2-DIST-STATE-PLUG-FLAG': '', 'WB14B2-GOOD-FAITH-VIOL-FLAG': '', 'WB14B2-WELL-OTHER-VIOL-FLAG': '', 'WB14B2-W3C-SURF-EQP-VIOL-FLAG': '', 'WB14B2-W3X-VIOL-FLAG': '', 'WB14B2-HB2259-W3X-PUB-ENT': '', 'WB14B2-HB2259-W3X-10PCT': 'Y', 'WB14B2-HB2259-W3X-BONDING': '', 'WB14B2-HB2259-W3X-H13-EOR': '', 'WB14B2-HB2259-W3X-AOP': '', 'WB14B2-HB2259-W3X-MIT': '', 'WB14B2-HB2259-W3X-ESCROW': '', 'WB14B2-W3X-FILING-KEY': 0, 'WB14B2-W3X-AOP-RECEIVED-DATE': None, 'WB14B2-W3X-AOP-FEE-RCVD-DATE': None, 'WB14B2-W3X-H15-FEE-RCVD-DATE': None, 'WB14B2-W3X-ESCROW-FUNDS': 0, 'WB14B2-60-DAY-LETTER-SENT-FLAG': 'Y', 'WB14B2-W1X-36-NEEDS-BOND-FLAG': '', 'WB14B2-W1X-36-TYPE-COVERAGE': '0', 'WB14B2-W1X-36-AMT-FILED': 0, 'WB14B2-W1X-36-SURETY': 0, 'WB14B2-W1X-36-EXP-DATE': None, 'WB14B2-W1X-36-BOND-NUMBER': '00000000000000000000'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '28', 'WB-14B2-RMK-LNE-CNT': 1, 'WB-14B2-RMK-DATE': '03/22/2011', 'WB-14B2-RMK-USERID': 'EXU005', 'WB-14B2-REMARKS': 'WB14B2 FOR OPER # 699848; APPL# 161974.  EXT STATUS IS: DENIED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '28', 'WB-14B2-RMK-LNE-CNT': 2, 'WB-14B2-RMK-DATE': '02/06/2012', 'WB-14B2-RMK-USERID': 'EXU005', 'WB-14B2-REMARKS': 'WB14B2 FOR OPER # 699848; APPL# 167060.  EXT STATUS IS: APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '28', 'WB-14B2-RMK-LNE-CNT': 3, 'WB-14B2-RMK-DATE': '02/19/2015', 'WB-14B2-RMK-USERID': 'EXU005', 'WB-14B2-REMARKS': 'WB14B2 FOR OPER # 699848; APPL# 188672.  EXT STATUS IS: APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '28', 'WB-14B2-RMK-LNE-CNT': 4, 'WB-14B2-RMK-DATE': '03/22/2017', 'WB-14B2-RMK-USERID': 'EXU005', 'WB-14B2-REMARKS': 'WB14B2 FOR OPER # 830589; APPL# 194835.  EXT STATUS IS: APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '28', 'WB-14B2-RMK-LNE-CNT': 5, 'WB-14B2-RMK-DATE': '01/05/2018', 'WB-14B2-RMK-USERID': 'EXU005', 'WB-14B2-REMARKS': 'WB14B2 FOR OPER # 830589; APPL# 206677.  EXT STATUS IS: APPROVED'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '25', 'WB-SB126-DESIGNATION-FLAG': 'A', 'WB-SB126-DESIG-EFFECTIVE-DATE': None, 'WB-SB126-DESIG-REVISED-DATE': None, 'WB-SB126-DESIG-LETTER-DATE': '09/16/2019', 'WB-SB126-CERT-EFFECT-DATE': None, 'WB-SB126-CERT-REVOKED-DATE': None, 'WB-SB126-CERT-DENIAL-DATE': None, 'WB-SB126-DENIAL-REASON-FLAG': '0'}
# 4200100001 {'RRC-TAPE-RECORD-ID': '27', 'WB-W3C-1YR-FLAG': 'Y', 'WB-W3C-1YR-FILED-DATE': '01/10/2012', 'WB-W3C-1YR-FILING-OPER': 699848, 'WB-W3C-5YR-FLAG': 'R', 'WB-W3C-5YR-FILED-DATE': 20120110, 'WB-W3C-5YR-FILING-OPER': 699848, 'WB-W3C-10YR-FLAG': 'R', 'WB-W3C-10YR-FILED-DATE': 20120131, 'WB-W3C-10YR-FILING-OPER': 699848, 'WB-W3C-14B2-REMOVAL-DATE': None, 'WB-W3C-EXTENSION-FLAG': '', 'WB-W3C-EXTENSION-DATE': None, 'WB-W3C-5YR-FLAG-PREVIOUS': '', 'WB-W3C-10YR-FLAG-PREVIOUS': ''}
# 4200100008 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100008, 'WB-NXT-AVAIL-SUFFIX': 1, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 1, 'WB-FIELD-DISTRICT': 6, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': None, 'WB-TOTAL-DEPTH': 0, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100008, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'Y', 'WB-PREVIOUS-API-NBR': 0, 'WB-COMPLETION-DATA-IND': 'Y', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 0, 'WB-DESIGNATION-HB-1975-FLAG': '0', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': None, 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 7420, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 0, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': '', 'WB-PEND-REMOVAL-14B2-FLAG': '', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '02', 'WB-OIL-GAS-INFO': 'G015885', 'WB-GAS-DIST': 6, 'WB-GAS-WELL-NO': '1A', 'WB-MULTI-WELL-REC-NBR': '', 'WB-API-SUFFIX': 0, 'WB-ACTIVE-INACTIVE-CODE': '', 'WB-DWN-HOLE-COMMINGLE-CODE': '', 'WB-CREATED-FROM-PI-FLAG': 'Y', 'WB-RULE-37-NBR': 0, 'WB-P-15': 'N', 'WB-P-12': 'N', 'WB-PLUG-DATE-POINTER': 19770623}
# 4200100008 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80159887, 'WB-FILE-DATE': '01/12/1984', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': None, 'WB-COMPL-DATE': None, 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 0, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 0, 'WB-REMARKS-IND': 'N', 'WB-ELEVATION': 0, 'WB-ELEVATION-CODE': '', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100008 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 1, 'WB-CAS-INCH': 0, 'WB-CAS-FRAC-NUM': 0, 'WB-CAS-FRAC-DENOM': 0, 'WB-CAS-WT-TABLE': 0, 'WB-CASING-DEPTH-SET': 0, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 0, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 0, 'WB-HOLE-FRAC-NUM': 0, 'WB-HOLE-FRAC-DENOM': 0, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 0}
# 4200100008 {'RRC-TAPE-RECORD-ID': '07', 'WB-PERF-COUNT': 1, 'WB-FROM-PERF': 7392, 'WB-TO-PERF': 7420, 'WB-OPEN-HOLE-CODE': ''}
# 4200100008 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 1, 'WB-ABSTRACT': '', 'WB-SURVEY': '', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 31.97988, 'WB-WGS84-LONGITUDE': -96.9796, 'WB-PLANE-ZONE': None, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': ''}
# 4200100008 {'RRC-TAPE-RECORD-ID': '14', 'WB-DATE-W3-FILED': '06/23/1977', 'WB-DATE-WELL-BORE-PLUGGED': '05/24/1977', 'WB-PLUG-TOTAL-DEPTH': 7590, 'WB-PLUG-CEMENT-COMP': 'B&H OILFIELD SUPPLIES', 'WB-PLUG-MUD-FILLED': 'Y', 'WB-PLUG-MUD-APPLIED': 'PUMP', 'WB-PLUG-MUD-WEIGHT': 95, 'WB-PLUG-DRIL-PERM-DATE': '12/16/1949', 'WB-PLUG-DRIL-PERM-NO': 0, 'WB-PLUG-DRIL-COMP-DATE': '05/06/1950', 'WB-PLUG-LOG-ATTACHED': '', 'WB-PLUG-LOG-RELEASED-TO': '', 'WB-PLUG-TYPE-LOG': '', 'WB-PLUG-FRESH-WATER-DEPTH': 0, 'WB-PLUG-UWQP': '0000000000000000000000000000000000000000', 'WB-PLUG-MATERIAL-LEFT': 'N', 'WB-OIL-GAS-INFO': 'G015885', 'WB-PLUG-GAS-DIST': 6, 'WB-PLUG-GAS-WELL-NO': '1A', 'WB-PLUG-TYPE-WELL': 'G', 'WB-PLUG-MULTI-COMPL-FLAG': 'N', 'WB-PLUG-CEM-AFF': 'N', 'WB-PLUG-13A': 'N', 'WB-PLUG-LOG-RELEASED-DATE': None, 'WB-PLUG-LOG-FILE-RBA': 0, 'WB-STATE-FUNDED-PLUG-NUMBER': 0}
# 4200100008 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 1, 'WB-PLUG-RMK-TYPE-CODE': 'W', 'WB-PLUG-REMARKS': 'THIS W-3 WAS KEYED ON 08/26/2010 FROM COPY W-3 FROM CENTRAL RECORDS.'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 1, 'WB-NBR-OF-CEMENT-SACKS': 20, 'WB-MEAS-TOP-OF-PLUG': 7250, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 7350, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 2, 'WB-NBR-OF-CEMENT-SACKS': 40, 'WB-MEAS-TOP-OF-PLUG': 908, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 1008, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 3, 'WB-NBR-OF-CEMENT-SACKS': 35, 'WB-MEAS-TOP-OF-PLUG': 608, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 708, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 4, 'WB-NBR-OF-CEMENT-SACKS': 10, 'WB-MEAS-TOP-OF-PLUG': 1, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 10, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100008 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 1, 'WB-PLUG-CAS-INCH': 9, 'WB-PLUG-CAS-FRAC-NUM': 5, 'WB-PLUG-CAS-FRAC-DENOM': 8, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 658, 'WB-PLUG-AMT-LEFT': 658, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100008 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 2, 'WB-PLUG-CAS-INCH': 5, 'WB-PLUG-CAS-FRAC-NUM': 1, 'WB-PLUG-CAS-FRAC-DENOM': 2, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 7589, 'WB-PLUG-AMT-LEFT': 6581, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100008 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 3, 'WB-PLUG-CAS-INCH': 2, 'WB-PLUG-CAS-FRAC-NUM': 3, 'WB-PLUG-CAS-FRAC-DENOM': 8, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 7450, 'WB-PLUG-AMT-LEFT': 0, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100037, 'WB-NXT-AVAIL-SUFFIX': 1, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 1, 'WB-FIELD-DISTRICT': 6, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': None, 'WB-TOTAL-DEPTH': 6020, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100037, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'Y', 'WB-PREVIOUS-API-NBR': 180394, 'WB-COMPLETION-DATA-IND': 'Y', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 3, 'WB-DESIGNATION-HB-1975-FLAG': '', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': None, 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 6020, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 0, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': '0', 'WB-PEND-REMOVAL-14B2-FLAG': 'N', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '02', 'WB-OIL-GAS-INFO': 'O0605312 201', 'WB-GAS-DIST': 0, 'WB-GAS-WELL-NO': '', 'WB-MULTI-WELL-REC-NBR': '0', 'WB-API-SUFFIX': 0, 'WB-ACTIVE-INACTIVE-CODE': '', 'WB-DWN-HOLE-COMMINGLE-CODE': '', 'WB-CREATED-FROM-PI-FLAG': 'N', 'WB-RULE-37-NBR': 0, 'WB-P-15': 'N', 'WB-P-12': 'N', 'WB-PLUG-DATE-POINTER': 20091111}
# 4200100037 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80069183, 'WB-FILE-DATE': '08/16/1993', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': '02/25/1993', 'WB-COMPL-DATE': None, 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 0, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 6565, 'WB-REMARKS-IND': 'Y', 'WB-ELEVATION': 0, 'WB-ELEVATION-CODE': '', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100037 {'RRC-TAPE-RECORD-ID': '04', 'WB-RMK-LNE-CNT': 1, 'WB-RMK-TYPE-CODE': '', 'WB-REMARKS': 'RECLASS TO INJECTION WELL.'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '04', 'WB-RMK-LNE-CNT': 2, 'WB-RMK-TYPE-CODE': '', 'WB-REMARKS': 'WELL REMOVED 11/03/2009; PLUGGED/ABANDONED.'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '05', 'WB-SEGMENT-COUNTER ': 1, 'WB-TUBING-INCHES': 2, 'WB-FR-NUMERATOR': 7, 'WB-FR-DENOMINATOR': 8, 'WB-DEPTH-SET': 5905, 'WB-PACKER-SET': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 1, 'WB-CAS-INCH': 8, 'WB-CAS-FRAC-NUM': 5, 'WB-CAS-FRAC-DENOM': 8, 'WB-CAS-WT-TABLE': 0, 'WB-CASING-DEPTH-SET': 304, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 0, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 0, 'WB-HOLE-FRAC-NUM': 0, 'WB-HOLE-FRAC-DENOM': 0, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 2, 'WB-CAS-INCH': 5, 'WB-CAS-FRAC-NUM': 1, 'WB-CAS-FRAC-DENOM': 2, 'WB-CAS-WT-TABLE': 0, 'WB-CASING-DEPTH-SET': 5978, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 0, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 0, 'WB-HOLE-FRAC-NUM': 0, 'WB-HOLE-FRAC-DENOM': 0, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '07', 'WB-PERF-COUNT': 1, 'WB-FROM-PERF': 5911, 'WB-TO-PERF': 5920, 'WB-OPEN-HOLE-CODE': ''}
# 4200100037 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80159887, 'WB-FILE-DATE': '01/12/1984', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': None, 'WB-COMPL-DATE': None, 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 0, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 0, 'WB-REMARKS-IND': 'N', 'WB-ELEVATION': 0, 'WB-ELEVATION-CODE': '', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100037 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 1, 'WB-CAS-INCH': 0, 'WB-CAS-FRAC-NUM': 0, 'WB-CAS-FRAC-DENOM': 0, 'WB-CAS-WT-TABLE': 0, 'WB-CASING-DEPTH-SET': 0, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 0, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 0, 'WB-HOLE-FRAC-NUM': 0, 'WB-HOLE-FRAC-DENOM': 0, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '07', 'WB-PERF-COUNT': 1, 'WB-FROM-PERF': 0, 'WB-TO-PERF': 5920, 'WB-OPEN-HOLE-CODE': ''}
# 4200100037 {'RRC-TAPE-RECORD-ID': '23', 'WB-H15-DATE-KEY': None, 'WB-H15-STATUS': 'C', 'WB-H15-OPERATOR': 53400, 'WB-H15-NEXT-TEST-DUE-DATE': None, 'WB-H15-DISTRICT': 6, 'WB-H15-FIELD': 79853500, 'WB-H15-HIST-WELLBORE-FLAG': '', 'WB-H15-HIST-WELL-DATE': None, 'WB-H15-W1X-WELL': '', 'WB-H15-OIL-GAS-CODE': 'O', 'WB-H15-LEASE-NBR': 5312, 'WB-H15-WELL-NBR': '201', 'WB-H15-GASID-NBR': 0, 'WB-H15-TEST-DATE': None, 'WB-H15-BASE-USABLE-WATER': 0, 'WB-H15-TYPE-TEST-FLAG': '', 'WB-H15-TOP-OF-FLUID': 0, 'WB-H15-FLUID-TEST-FLAG': '', 'WB-H15-MECH-INTEG-TEST-FLAG': '', 'WB-H15-MECH-TEST-REASON-FLAG': '', 'WB-H15-ALTERNATE-TEST-PERIOD': 0, 'WB-H15-OTHER-MIT-TEST-TYPE': '', 'WB-H15-STATUS-DATE': 19970221, 'WB-H15-NO-DATE-WELL-FLAG': 'Y', 'WB-H15-RECORD-FROM-EDI-FLAG': '', 'WB-H15-KEYED-DATE': None, 'WB-H15-CHANGED-DATE': None, 'WB-H15-PREVIOUS-STATUS': '', 'WB-H15-UIC-TEST-FLAG': '', 'WB-H15-2YRS-APPROVED-FLAG': '0', 'WB-H15-MAIL-HOLD-FLAG': '0', 'WB-H15-10YR-INACTIVE-FLAG': '0', 'WB-H15-W3X-WELL-FLAG': '0'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 1, 'WB-H15-REMARK-TEXT': '09/29/95 - UIC STATUS - UIC JURISDICTION'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '24', 'WB-H15-REMARK-KEY': 2, 'WB-H15-REMARK-TEXT': 'COMPLIANT   02/21/97'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 1, 'WB-ABSTRACT': '', 'WB-SURVEY': '', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 31.55752, 'WB-WGS84-LONGITUDE': -95.54811, 'WB-PLANE-ZONE': None, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': ''}
# 4200100037 {'RRC-TAPE-RECORD-ID': '14', 'WB-DATE-W3-FILED': '11/11/2009', 'WB-DATE-WELL-BORE-PLUGGED': '11/03/2009', 'WB-PLUG-TOTAL-DEPTH': 6020, 'WB-PLUG-CEMENT-COMP': 'WTH, INC.', 'WB-PLUG-MUD-FILLED': 'Y', 'WB-PLUG-MUD-APPLIED': 'PUMP', 'WB-PLUG-MUD-WEIGHT': 98, 'WB-PLUG-DRIL-PERM-DATE': None, 'WB-PLUG-DRIL-PERM-NO': 0, 'WB-PLUG-DRIL-COMP-DATE': None, 'WB-PLUG-LOG-ATTACHED': '', 'WB-PLUG-LOG-RELEASED-TO': '', 'WB-PLUG-TYPE-LOG': '', 'WB-PLUG-FRESH-WATER-DEPTH': 2900, 'WB-PLUG-UWQP': '0000000000000000000000000000000000000000', 'WB-PLUG-MATERIAL-LEFT': 'N', 'WB-OIL-GAS-INFO': 'O0605312 201', 'WB-PLUG-GAS-DIST': 0, 'WB-PLUG-GAS-WELL-NO': '', 'WB-PLUG-TYPE-WELL': 'S', 'WB-PLUG-MULTI-COMPL-FLAG': 'N', 'WB-PLUG-CEM-AFF': 'N', 'WB-PLUG-13A': 'N', 'WB-PLUG-LOG-RELEASED-DATE': None, 'WB-PLUG-LOG-FILE-RBA': 0, 'WB-STATE-FUNDED-PLUG-NUMBER': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 1, 'WB-PLUG-RMK-TYPE-CODE': 'W', 'WB-PLUG-REMARKS': 'THIS W-3 WAS KEYED ON 12/14/2009.'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 2, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'PLUG #3 & #4 CUT TO 25 SX BALANCED PLUGS W/APPROVAL FROM CHRIS EVERS,'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 3, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'DUE TO NO INJECTION RATE AFTER PERFORATIONS AT EACH INTERVAL. PLUG #5'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 4, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'MUST WITNESS PLUG WITNESSED BY MR. SCOTT BRUMFIELD FIELD INSPECTOR'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 5, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'W/RRC TEXAS ALL PLUGS WITNESSED BY DICK BRIDGES W/BARTEE CONSTRUCTION.'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 1, 'WB-NBR-OF-CEMENT-SACKS': 25, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 5850, 'WB-PLUG-CALC-TOP': 5700, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 2, 'WB-NBR-OF-CEMENT-SACKS': 25, 'WB-MEAS-TOP-OF-PLUG': 2810, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 2960, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 3, 'WB-NBR-OF-CEMENT-SACKS': 25, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 875, 'WB-PLUG-CALC-TOP': 775, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 4, 'WB-NBR-OF-CEMENT-SACKS': 25, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 675, 'WB-PLUG-CALC-TOP': 575, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 5, 'WB-NBR-OF-CEMENT-SACKS': 75, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 475, 'WB-PLUG-CALC-TOP': 250, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 6, 'WB-NBR-OF-CEMENT-SACKS': 5, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 15, 'WB-PLUG-CALC-TOP': 3, 'WB-PLUG-TYPE-CEMENT': 'H'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 1, 'WB-PLUG-CAS-INCH': 8, 'WB-PLUG-CAS-FRAC-NUM': 5, 'WB-PLUG-CAS-FRAC-DENOM': 8, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 304, 'WB-PLUG-AMT-LEFT': 304, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 2, 'WB-PLUG-CAS-INCH': 5, 'WB-PLUG-CAS-FRAC-NUM': 1, 'WB-PLUG-CAS-FRAC-DENOM': 2, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 5978, 'WB-PLUG-AMT-LEFT': 5978, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100037 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 1, 'WB-PLUG-FROM-PERF': 5911, 'WB-PLUG-TO-PERF': 5920, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 2, 'WB-PLUG-FROM-PERF': 874, 'WB-PLUG-TO-PERF': 875, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 3, 'WB-PLUG-FROM-PERF': 674, 'WB-PLUG-TO-PERF': 675, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100037 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 4, 'WB-PLUG-FROM-PERF': 474, 'WB-PLUG-TO-PERF': 475, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100038, 'WB-NXT-AVAIL-SUFFIX': 0, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 0, 'WB-FIELD-DISTRICT': 0, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': None, 'WB-TOTAL-DEPTH': 0, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100038, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'Y', 'WB-PREVIOUS-API-NBR': 0, 'WB-COMPLETION-DATA-IND': 'N', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 0, 'WB-DESIGNATION-HB-1975-FLAG': '0', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': None, 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 0, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 0, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': '0', 'WB-PEND-REMOVAL-14B2-FLAG': '0', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 38, 'WB-ABSTRACT': '', 'WB-SURVEY': '', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 32.8878, 'WB-WGS84-LONGITUDE': -95.994281, 'WB-PLANE-ZONE': 0, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': '0'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '14', 'WB-DATE-W3-FILED': '05/07/1975', 'WB-DATE-WELL-BORE-PLUGGED': '05/05/1975', 'WB-PLUG-TOTAL-DEPTH': 4000, 'WB-PLUG-CEMENT-COMP': 'KNIGHT CASING PULLING CO.', 'WB-PLUG-MUD-FILLED': 'Y', 'WB-PLUG-MUD-APPLIED': 'PUMP', 'WB-PLUG-MUD-WEIGHT': 100, 'WB-PLUG-DRIL-PERM-DATE': None, 'WB-PLUG-DRIL-PERM-NO': 0, 'WB-PLUG-DRIL-COMP-DATE': None, 'WB-PLUG-LOG-ATTACHED': 'N', 'WB-PLUG-LOG-RELEASED-TO': '', 'WB-PLUG-TYPE-LOG': '', 'WB-PLUG-FRESH-WATER-DEPTH': 700, 'WB-PLUG-UWQP': '0000000000000000000000000000000000000000', 'WB-PLUG-MATERIAL-LEFT': 'N', 'WB-OIL-GAS-INFO': '', 'WB-PLUG-GAS-DIST': 6, 'WB-PLUG-GAS-WELL-NO': '2__', 'WB-PLUG-TYPE-WELL': 'D', 'WB-PLUG-MULTI-COMPL-FLAG': 'N', 'WB-PLUG-CEM-AFF': 'N', 'WB-PLUG-13A': 'N', 'WB-PLUG-LOG-RELEASED-DATE': None, 'WB-PLUG-LOG-FILE-RBA': 0, 'WB-STATE-FUNDED-PLUG-NUMBER': 0}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 1, 'WB-PLUG-RMK-TYPE-CODE': 'W', 'WB-PLUG-REMARKS': 'THIS W-3 WAS KEYED ON 06/06/2012. KEYED AS DRY, OIL LEASE NOT ON'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 3, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'SCHEDULE. REPLUG/LEAKING - ORIGINALLY PLUGGED 04/02/1946'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 4, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'REMOVED TOP PLUG OF 10\'OF SOLID CEMENT; WENT IN HOLE 775\' OF 2-3/8"'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 5, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'TUBING AND SET BOTTOM PLUG TYING PLUG FROM OPEN HOLE INTO 7" CASING.'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 6, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'CAME OUT OF HOLE WITH 2-3/8" TUBING. WELL WAS DORMANT. SET 10 SACK'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 7, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'TOP PLUG. PLACED CAP ON 7" CASING AND FILLED AND LEVELED LOCATION.'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 1, 'WB-NBR-OF-CEMENT-SACKS': 40, 'WB-MEAS-TOP-OF-PLUG': 600, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 700, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 2, 'WB-NBR-OF-CEMENT-SACKS': 10, 'WB-MEAS-TOP-OF-PLUG': 1, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 10, 'WB-PLUG-CALC-TOP': 0, 'WB-PLUG-TYPE-CEMENT': 'COMMON'}
# 4200100038 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 1, 'WB-PLUG-CAS-INCH': 7, 'WB-PLUG-CAS-FRAC-NUM': 0, 'WB-PLUG-CAS-FRAC-DENOM': 0, 'WB-PLUG-WGT-WHOLE': 0, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 0, 'WB-PLUG-AMT-LEFT': 2500, 'WB-PLUG-HOLE-INCH': 0, 'WB-PLUG-HOLE-FRAC-NUM': 0, 'WB-PLUG-HOLE-FRAC-DENOM': 0}
# 4200100038 {'RRC-TAPE-RECORD-ID': '19', 'WB-PLUG-FIELD-NO': 0, 'WB-PLUG-FIELD-NAME': 'CAYUGA', 'WB-PLUG-OPER-NO': '000000', 'WB-PLUG-OPER-NAME': 'CAIN, WOFFORD', 'WB-PLUG-LEASE-NAME': 'WILLIAMS, A. G.'}
# ...
# 4200100136 {'RRC-TAPE-RECORD-ID': '04', 'WB-RMK-LNE-CNT': 1, 'WB-RMK-TYPE-CODE': '', 'WB-REMARKS': 'WELL REMOVED 09/06/91; PLUGGED/ABANDONED.'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 1, 'WB-ABSTRACT': '', 'WB-SURVEY': '', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 32.26893, 'WB-WGS84-LONGITUDE': -95.509934, 'WB-PLANE-ZONE': None, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': ''}
# 4200100136 {'RRC-TAPE-RECORD-ID': '14', 'WB-DATE-W3-FILED': '09/13/1991', 'WB-DATE-WELL-BORE-PLUGGED': '09/06/1991', 'WB-PLUG-TOTAL-DEPTH': 10170, 'WB-PLUG-CEMENT-COMP': 'HALLIBURTON SERVICES', 'WB-PLUG-MUD-FILLED': 'Y', 'WB-PLUG-MUD-APPLIED': 'PUMP', 'WB-PLUG-MUD-WEIGHT': 100, 'WB-PLUG-DRIL-PERM-DATE': '03/18/1964', 'WB-PLUG-DRIL-PERM-NO': 0, 'WB-PLUG-DRIL-COMP-DATE': '05/12/1964', 'WB-PLUG-LOG-ATTACHED': '', 'WB-PLUG-LOG-RELEASED-TO': '', 'WB-PLUG-TYPE-LOG': '', 'WB-PLUG-FRESH-WATER-DEPTH': 2000, 'WB-PLUG-UWQP': '0000000000000000000000000000000000000000', 'WB-PLUG-MATERIAL-LEFT': 'N', 'WB-OIL-GAS-INFO': 'O0604853 960', 'WB-PLUG-GAS-DIST': 0, 'WB-PLUG-GAS-WELL-NO': '', 'WB-PLUG-TYPE-WELL': 'O', 'WB-PLUG-MULTI-COMPL-FLAG': 'N', 'WB-PLUG-CEM-AFF': 'N', 'WB-PLUG-13A': 'N', 'WB-PLUG-LOG-RELEASED-DATE': None, 'WB-PLUG-LOG-FILE-RBA': 0, 'WB-STATE-FUNDED-PLUG-NUMBER': 0}
# 4200100136 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 1, 'WB-PLUG-RMK-TYPE-CODE': 'W', 'WB-PLUG-REMARKS': 'THIS W-3 WAS KEYED ON 10/21/91.'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 2, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'PLUG #1 - 35 SXS PLACED BELOW RETAINER & 35 SKS PLACED ABOVE RETAINER.'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 3, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "RETAINER DEPTH 9800' - PLUG #2 RETAINER @ 5000' - 245 SKS. BELOW"}
# 4200100136 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 4, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'RETAINER & 4.7 SKS ON TOP OF RETAINER - PLUG #3 200 SKS PLACED BELOW'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 5, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "RETAINER @ 1582' - PLUG #4 WAS PLACED THROUGH PERFS @ 400' & BALANCED."}
# 4200100136 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 1, 'WB-NBR-OF-CEMENT-SACKS': 70, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 9800, 'WB-PLUG-CALC-TOP': 9198, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 2, 'WB-NBR-OF-CEMENT-SACKS': 250, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 5000, 'WB-PLUG-CALC-TOP': 4936, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 3, 'WB-NBR-OF-CEMENT-SACKS': 200, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 1582, 'WB-PLUG-CALC-TOP': 1582, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 4, 'WB-NBR-OF-CEMENT-SACKS': 40, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 248, 'WB-PLUG-CALC-TOP': 277, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 5, 'WB-NBR-OF-CEMENT-SACKS': 10, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 10, 'WB-PLUG-CALC-TOP': 5, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 1, 'WB-PLUG-CAS-INCH': 8, 'WB-PLUG-CAS-FRAC-NUM': 5, 'WB-PLUG-CAS-FRAC-DENOM': 8, 'WB-PLUG-WGT-WHOLE': 24, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 2216, 'WB-PLUG-AMT-LEFT': 2211, 'WB-PLUG-HOLE-INCH': 12, 'WB-PLUG-HOLE-FRAC-NUM': 1, 'WB-PLUG-HOLE-FRAC-DENOM': 4}
# 4200100136 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 2, 'WB-PLUG-CAS-INCH': 4, 'WB-PLUG-CAS-FRAC-NUM': 1, 'WB-PLUG-CAS-FRAC-DENOM': 2, 'WB-PLUG-WGT-WHOLE': 11, 'WB-PLUG-WGT-TENTHS': 6, 'WB-PLUG-AMT-PUT': 10157, 'WB-PLUG-AMT-LEFT': 10152, 'WB-PLUG-HOLE-INCH': 7, 'WB-PLUG-HOLE-FRAC-NUM': 7, 'WB-PLUG-HOLE-FRAC-DENOM': 8}
# 4200100136 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 1, 'WB-PLUG-FROM-PERF': 9930, 'WB-PLUG-TO-PERF': 9940, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100136 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 2, 'WB-PLUG-FROM-PERF': 9429, 'WB-PLUG-TO-PERF': 9946, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100137, 'WB-NXT-AVAIL-SUFFIX': 1, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 1, 'WB-FIELD-DISTRICT': 6, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': '01/28/1963', 'WB-TOTAL-DEPTH': 10325, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100137, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'Y', 'WB-PREVIOUS-API-NBR': 0, 'WB-COMPLETION-DATA-IND': 'Y', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 0, 'WB-DESIGNATION-HB-1975-FLAG': '0', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': None, 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 10325, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 0, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': '', 'WB-PEND-REMOVAL-14B2-FLAG': '', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '02', 'WB-OIL-GAS-INFO': 'O0604853 961WG', 'WB-GAS-DIST': 0, 'WB-GAS-WELL-NO': '', 'WB-MULTI-WELL-REC-NBR': '1', 'WB-API-SUFFIX': 0, 'WB-ACTIVE-INACTIVE-CODE': '', 'WB-DWN-HOLE-COMMINGLE-CODE': '', 'WB-CREATED-FROM-PI-FLAG': 'N', 'WB-RULE-37-NBR': 0, 'WB-P-15': 'N', 'WB-P-12': 'N', 'WB-PLUG-DATE-POINTER': 19900828}
# 4200100137 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80129268, 'WB-FILE-DATE': '07/31/1987', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': '07/16/1987', 'WB-COMPL-DATE': '01/28/1963', 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 9939, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 0, 'WB-REMARKS-IND': 'N', 'WB-ELEVATION': 353, 'WB-ELEVATION-CODE': 'DF', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '06-55176', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100137 {'RRC-TAPE-RECORD-ID': '05', 'WB-SEGMENT-COUNTER ': 1, 'WB-TUBING-INCHES': 2, 'WB-FR-NUMERATOR': 3, 'WB-FR-DENOMINATOR': 8, 'WB-DEPTH-SET': 9830, 'WB-PACKER-SET': 9830}
# 4200100137 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 1, 'WB-CAS-INCH': 9, 'WB-CAS-FRAC-NUM': 5, 'WB-CAS-FRAC-DENOM': 8, 'WB-CAS-WT-TABLE': 3600000, 'WB-CASING-DEPTH-SET': 2201, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 700, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 12, 'WB-HOLE-FRAC-NUM': 1, 'WB-HOLE-FRAC-DENOM': 4, 'WB-TOP-OF-CEMENT-CASING': '', 'WB-AMOUNT-CASING-LEFT': 90000}
# 4200100137 {'RRC-TAPE-RECORD-ID': '06', 'WB-CASING-COUNT': 2, 'WB-CAS-INCH': 5, 'WB-CAS-FRAC-NUM': 1, 'WB-CAS-FRAC-DENOM': 2, 'WB-CAS-WT-TABLE': 1700000, 'WB-CASING-DEPTH-SET': 10324, 'WB-MLTI-STG-TOOL-DPTH': 0, 'WB-AMOUNT-OF-CEMENT': 650, 'WB-CEMENT-MEASUREMENT': 'S', 'WB-HOLE-INCH': 8, 'WB-HOLE-FRAC-NUM': 3, 'WB-HOLE-FRAC-DENOM': 4, 'WB-TOP-OF-CEMENT-CASING': '8950', 'WB-AMOUNT-CASING-LEFT': 90000}
# 4200100137 {'RRC-TAPE-RECORD-ID': '07', 'WB-PERF-COUNT': 1, 'WB-FROM-PERF': 9880, 'WB-TO-PERF': 9886, 'WB-OPEN-HOLE-CODE': ''}
# 4200100137 {'RRC-TAPE-RECORD-ID': '09', 'WB-FORMATION-CNTR': 1, 'WB-FORMATION-NAME': 'AUSTIN', 'WB-FORMATION-DEPTH': 4740}
# 4200100137 {'RRC-TAPE-RECORD-ID': '09', 'WB-FORMATION-CNTR': 2, 'WB-FORMATION-NAME': 'WOODBINE', 'WB-FORMATION-DEPTH': 5060}
# 4200100137 {'RRC-TAPE-RECORD-ID': '09', 'WB-FORMATION-CNTR': 3, 'WB-FORMATION-NAME': 'JAMES LIME', 'WB-FORMATION-DEPTH': 9880}
# 4200100137 {'RRC-TAPE-RECORD-ID': '09', 'WB-FORMATION-CNTR': 4, 'WB-FORMATION-NAME': 'PETTIT', 'WB-FORMATION-DEPTH': 10198}
# 4200100137 {'RRC-TAPE-RECORD-ID': '10', 'WB-SQUEEZE-CNTR ': 1, 'WB-SQUEEZE-UPPER-DEPTH ': 9880, 'WB-SQUEEZE-LOWER-DEPTH': 9886, 'WB-SQUEEZE-KIND-AMOUNT ': '0 GALS 15% HCL                                  00'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '03', 'WB-FILE-KEY': 80159887, 'WB-FILE-DATE': '01/12/1984', 'WB-EXCEPT-RULE-11': 'N', 'WB-CEMENT-AFFIDAVIT': 'N', 'WB-G-5': 'N', 'WB-W-12': 'N', 'WB-DIR-SURVEY': 'N', 'WB-W2-G1-DATE ': None, 'WB-COMPL-DATE': None, 'WB-DRL-COMPL-DATE': None, 'WB-PLUGB-DEPTH1': 0, 'WB-PLUGB-DEPTH2': 0, 'WB-WATER-INJECTION-NBR': '', 'WB-SALT-WTR-NBR': 0, 'WB-REMARKS-IND': 'N', 'WB-ELEVATION': 0, 'WB-ELEVATION-CODE': '', 'WB-LOG-FILE-RBA': 0, 'WB-DOCKET-NBR': '', 'WB-PSA-WELL-FLAG': '', 'WB-ALLOCATION-WELL-FLAG': ''}
# 4200100137 {'RRC-TAPE-RECORD-ID': '13', 'WB-LOC-COUNTY': 1, 'WB-ABSTRACT': '27', 'WB-SURVEY': 'T. GOSS SURV', 'WB-BLOCK-NUMBER': '', 'WB-SECTION': '', 'WB-ALT-SECTION': '', 'WB-ALT-ABSTRACT': '', 'WB-FEET-FROM-SUR-SECT-1': 0, 'WB-DIREC-FROM-SUR-SECT-1': '', 'WB-FEET-FROM-SUR-SECT-2': 0, 'WB-DIREC-FROM-SUR-SECT-2': '', 'WB-WGS84-LATITUDE': 32.3664, 'WB-WGS84-LONGITUDE': -95.504523, 'WB-PLANE-ZONE': 0, 'WB-PLANE-COORDINATE-EAST': None, 'WB-PLANE-COORDINATE-NORTH': None, 'WB-VERIFICATION-FLAG': '0'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '14', 'WB-DATE-W3-FILED': '08/28/1990', 'WB-DATE-WELL-BORE-PLUGGED': '08/09/1990', 'WB-PLUG-TOTAL-DEPTH': 10325, 'WB-PLUG-CEMENT-COMP': 'HALLIBURTON SERVICES', 'WB-PLUG-MUD-FILLED': 'Y', 'WB-PLUG-MUD-APPLIED': 'PUMP', 'WB-PLUG-MUD-WEIGHT': 102, 'WB-PLUG-DRIL-PERM-DATE': '12/03/1962', 'WB-PLUG-DRIL-PERM-NO': 0, 'WB-PLUG-DRIL-COMP-DATE': '01/18/1963', 'WB-PLUG-LOG-ATTACHED': '', 'WB-PLUG-LOG-RELEASED-TO': '', 'WB-PLUG-TYPE-LOG': '', 'WB-PLUG-FRESH-WATER-DEPTH': 1800, 'WB-PLUG-UWQP': '0000000000000000000000000000000000000000', 'WB-PLUG-MATERIAL-LEFT': 'N', 'WB-OIL-GAS-INFO': 'O0604853 961WG', 'WB-PLUG-GAS-DIST': 0, 'WB-PLUG-GAS-WELL-NO': '', 'WB-PLUG-TYPE-WELL': 'O', 'WB-PLUG-MULTI-COMPL-FLAG': 'N', 'WB-PLUG-CEM-AFF': 'N', 'WB-PLUG-13A': 'N', 'WB-PLUG-LOG-RELEASED-DATE': None, 'WB-PLUG-LOG-FILE-RBA': 0, 'WB-STATE-FUNDED-PLUG-NUMBER': 0}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 1, 'WB-PLUG-RMK-TYPE-CODE': 'W', 'WB-PLUG-REMARKS': 'THIS W-3 WAS KEYED ON 10/16/90.'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 2, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "1ST PLUG: EZSV SET @ 9787' - PUMPED 25 SKS (29.5 CUFT CMT) BELOW EZSV"}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 3, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "& SQUEEZE. 2ND PLUG: EZSV SET @ 4900' - PUMPED 145 SKS (171 CUFT CMT)"}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 4, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': 'BELOW EZSV & SQUEEZE. LEFT 5 SKS CMT OF TOP OF EZSV (SQUEEZ PERFS @'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 5, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "5200'). 3RD PLUG: EZSV SET @ 1600' - PUMPED 215 SKS (254 CUFT CMT)"}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 6, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "BELOW EZSV & SQUEEZE PERFS @ 2250'. 4TH PLUG: PERFS @ 400' BALANCED"}
# 4200100137 {'RRC-TAPE-RECORD-ID': '15', 'WB-PLUG-RMK-LNE-CNT': 7, 'WB-PLUG-RMK-TYPE-CODE': '', 'WB-PLUG-REMARKS': "PLUG IN 5-1/2 CASING & 9-5/8 CSG - 144' PLUG."}
# 4200100137 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 1, 'WB-NBR-OF-CEMENT-SACKS': 100, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 9944, 'WB-PLUG-CALC-TOP': 9109, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 2, 'WB-NBR-OF-CEMENT-SACKS': 150, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 5200, 'WB-PLUG-CALC-TOP': 4880, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 3, 'WB-NBR-OF-CEMENT-SACKS': 220, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 2250, 'WB-PLUG-CALC-TOP': 1580, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 4, 'WB-NBR-OF-CEMENT-SACKS': 50, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 400, 'WB-PLUG-CALC-TOP': 256, 'WB-PLUG-TYPE-CEMENT': 'PREM'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '16', 'WB-PLUG-NUMBER': 5, 'WB-NBR-OF-CEMENT-SACKS': 10, 'WB-MEAS-TOP-OF-PLUG': 0, 'WB-BOTTOM-TUBE-PIPE-DEPTH': 25, 'WB-PLUG-CALC-TOP': 3, 'WB-PLUG-TYPE-CEMENT': ''}
# 4200100137 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 1, 'WB-PLUG-CAS-INCH': 9, 'WB-PLUG-CAS-FRAC-NUM': 5, 'WB-PLUG-CAS-FRAC-DENOM': 8, 'WB-PLUG-WGT-WHOLE': 36, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 2201, 'WB-PLUG-AMT-LEFT': 2201, 'WB-PLUG-HOLE-INCH': 12, 'WB-PLUG-HOLE-FRAC-NUM': 1, 'WB-PLUG-HOLE-FRAC-DENOM': 4}
# 4200100137 {'RRC-TAPE-RECORD-ID': '17', 'WB-PLG-CAS-COUNTER': 2, 'WB-PLUG-CAS-INCH': 5, 'WB-PLUG-CAS-FRAC-NUM': 1, 'WB-PLUG-CAS-FRAC-DENOM': 2, 'WB-PLUG-WGT-WHOLE': 17, 'WB-PLUG-WGT-TENTHS': 0, 'WB-PLUG-AMT-PUT': 10325, 'WB-PLUG-AMT-LEFT': 10325, 'WB-PLUG-HOLE-INCH': 8, 'WB-PLUG-HOLE-FRAC-NUM': 3, 'WB-PLUG-HOLE-FRAC-DENOM': 4}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 1, 'WB-PLUG-FROM-PERF': 10201, 'WB-PLUG-TO-PERF': 10224, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 2, 'WB-PLUG-FROM-PERF': 9960, 'WB-PLUG-TO-PERF': 9970, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 3, 'WB-PLUG-FROM-PERF': 9880, 'WB-PLUG-TO-PERF': 9944, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 4, 'WB-PLUG-FROM-PERF': 5198, 'WB-PLUG-TO-PERF': 5200, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 5, 'WB-PLUG-FROM-PERF': 2248, 'WB-PLUG-TO-PERF': 2250, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100137 {'RRC-TAPE-RECORD-ID': '18', 'WB-PLUG-PERF-COUNTER': 6, 'WB-PLUG-FROM-PERF': 398, 'WB-PLUG-TO-PERF': 400, 'WB-PLUG-OPEN-HOLE-INDICATOR': 'N'}
# 4200100138 {'RRC-TAPE-RECORD-ID': '01', 'WELL-BORE-API-ROOT': 100138, 'WB-NXT-AVAIL-SUFFIX': 1, 'WB-NXT-AVAIL-HOLE-CHGE-NBR': 1, 'WB-FIELD-DISTRICT': 6, 'WB-RES-CNTY-CODE': 1, 'WB-ORIG-COMPL-DATE': None, 'WB-TOTAL-DEPTH': 0, 'WB-VALID-FLUID-LEVEL': 0, 'WB-CERTIFICATION-REVOKED-DATE': None, 'WB-CERTIFICATION-DENIAL-DATE': None, 'WB-DENIAL-REASON-FLAG': '0', 'WB-ERROR-API-ASSIGN-CODE': '', 'WB-REFER-CORRECT-API-NBR': 0, 'WB-DUMMY-API-NUMBER': 100138, 'WB-DATE-DUMMY-REPLACED': None, 'WB-NEWEST-DRL-PMT-NBR': 0, 'WB-CANCEL-EXPIRE-CODE': '', 'WB-EXCEPT-13-A': 'N', 'WB-FRESH-WATER-FLAG': 'N', 'WB-PLUG-FLAG': 'Y', 'WB-PREVIOUS-API-NBR': 0, 'WB-COMPLETION-DATA-IND': 'Y', 'WB-HIST-DATE-SOURCE-FLAG': 0, 'WB-EX14B2-COUNT': 0, 'WB-DESIGNATION-HB-1975-FLAG': '0', 'WB-DESIGNATION-EFFECTIVE-DATE': None, 'WB-DESIGNATION-REVISED-DATE': None, 'WB-DESIGNATION-LETTER-DATE': None, 'WB-CERTIFICATION-EFFECT-DATE': None, 'WB-WATER-LAND-CODE': 'L', 'WB-TOTAL-BONDED-DEPTH': 9959, 'WB-OVERRIDE-EST-PLUG-COST': 0, 'WB-SHUT-IN-DATE': 0, 'WB-OVERRIDE-BONDED-DEPTH': 0, 'WB-SUBJ-TO-14B2-FLAG': '', 'WB-PEND-REMOVAL-14B2-FLAG': '', 'WB-ORPHAN-WELL-HOLD-FLAG': '0', 'WB-W3X-WELL-FLAG': '0'}
# 4200100138 {'RRC-TAPE-RECORD-ID': '02', 'WB-OIL-GAS-INFO': 'O0604853 962', 'WB-GAS-DIST': 0, 'WB-GAS-WELL-NO': '', 'WB-MULTI-WELL-REC-NBR': '1', 'WB-API-SUFFIX': 0, 'WB-ACTIVE-INACTIVE-CODE': '', 'WB-DWN-HOLE-COMMINGLE-CODE': '', 'WB-CREATED-FROM-PI-FLAG': 'N', 'WB-RULE-37-NBR': 0, 'WB-P-15': 'N', 'WB-P-12': 'N', 'WB-PLUG-DATE-POINTER': 19900917}
